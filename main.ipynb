# %%
# Mount Google Drive
from google.colab import drive
drive.mount("/content/drive")

! pip install kaggle --quiet
# Out:
# Mounted at /content/drive

# %%
# config kaggle API
kaggle_api_path = "/content/drive/MyDrive/410_project/kaggle.json"

! mkdir ~/.kaggle
! cp $kaggle_api_path ~/.kaggle/

# change file permissions
! chmod 600 ~/.kaggle/kaggle.json

# %%
# Download dataset
competition_name = "jigsaw-toxic-comment-classification-challenge"
! kaggle competitions download -c {competition_name}

! mkdir kaggle_data
! unzip {competition_name + ".zip"} -d kaggle_data

# Unmount Google Drive
drive.flush_and_unmount()
# Out:
# Downloading jigsaw-toxic-comment-classification-challenge.zip to /content
#  85% 45.0M/52.6M [00:00<00:00, 60.1MB/s]
# 100% 52.6M/52.6M [00:00<00:00, 62.7MB/s]
# Archive:  jigsaw-toxic-comment-classification-challenge.zip
#   inflating: kaggle_data/sample_submission.csv.zip
#   inflating: kaggle_data/test.csv.zip
#   inflating: kaggle_data/test_labels.csv.zip
#   inflating: kaggle_data/train.csv.zip

# %%
! ls kaggle_data
# Out:
# sample_submission.csv.zip  test.csv.zip  test_labels.csv.zip  train.csv.zip

# %%
# !pip install pandas --quiet

# %%
# Demo few rows of dataset
import pandas as pd

df = pd.read_csv('/content/kaggle_data/train.csv.zip')
df.sample(5)
# Out:
#                       id                                       comment_text  \
# 146049  26296671a2c89398  Please do not put promotional remarks in the r...
# 47030   7da4fd29df5cc596  Well thank you. If I am getting angry and aggr...
# 91522   f4b7100856e95258  Thanks ElKevbo, sorry I didn't know that. 96.2...
# 68639   b7a132c6c451f39f  Yo why am i teh banzoured its not fun i want t...
# 115404  6929a5849d89be1a  I did and your tagging is without merit. I hav...
#
#         toxic  severe_toxic  obscene  threat  insult  identity_hate
# 146049      0             0        0       0       0              0
# 47030       0             0        0       0       0              0
# 91522       0             0        0       0       0              0
# 68639       1             0        0       0       0              0
# 115404      0             0        0       0       0              0
